# %%
from flask import Flask, render_template, request, jsonify

# %%
import import_ipynb
import Response_generator

# %%
app = Flask(__name__)

# %%
@app.route('/')# mapping the URLs to a specific function that will handle the logic for that URL
def index():
    return render_template('index.html')#render_template is used to generate output from 
#a template file based on the Jinja2 engine that
#is found in the application's templates folder.

# %%
@app.route('/get')
def get_bot_response():
    message = request.args.get('msg')
    response = ""
    if message:
        response = Response_generator.generate_response(message)
        return str(response)
    else:
         return "Missing Data!"

# %%
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [24/Apr/2026 21:17:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2026 21:17:04] "GET /static/images/slider.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2026 21:17:04] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [24/Apr/2026 21:17:21] "GET /get?msg=hello HTTP/1.1" 200 -
# greeting
# 127.0.0.1 - - [24/Apr/2026 21:17:34] "GET /get?msg=hi HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2026 21:17:34] "GET /get?msg=how%20are%20you? HTTP/1.1" 200 -
# greeting
# hours
# 127.0.0.1 - - [24/Apr/2026 21:17:50] "GET /get?msg=good HTTP/1.1" 200 -
# goodbye
# 127.0.0.1 - - [24/Apr/2026 21:18:13] "GET /get?msg=give%20me%20vegetarian%20menu HTTP/1.1" 200 -
# veg_pizza
# 127.0.0.1 - - [24/Apr/2026 21:18:31] "GET /get?msg=i%20want%20punjabi%20food HTTP/1.1" 200 -
# nonveg_soup
# 127.0.0.1 - - [24/Apr/2026 21:18:49] "GET /get?msg=give%20me%20veg%20options HTTP/1.1" 200 -
# veg_soup
# 127.0.0.1 - - [24/Apr/2026 21:19:03] "GET /get?msg=give%20me%20veg%20menu HTTP/1.1" 200 -
# veg_pizza
# 127.0.0.1 - - [24/Apr/2026 21:19:30] "GET /get?msg=dessert HTTP/1.1" 200 -
# dessert
# 127.0.0.1 - - [24/Apr/2026 21:19:47] "GET /get?msg=available_tables HTTP/1.1" 200 -
# sanitation
